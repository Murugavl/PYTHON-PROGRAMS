# %% [markdown]
# <a href="https://colab.research.google.com/github/Murugavl/PYTHON-PROGRAMS/blob/main/Line_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[5,6,8,10,15]
y=[20,30,40,50,55]
plt.plot(x,y)
plt.title("STUDENT DATA-LINE GRAPH")
plt.ylabel('Present %')
plt.xlabel('Roll.no')
plt.show()
